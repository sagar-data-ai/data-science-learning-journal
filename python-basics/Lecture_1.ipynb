# %% [markdown]
# # **Lecture 1 fundamental of Python**

# %% [markdown]
# # 1. Python Output

# %% [markdown]
# # **Let's Start with Basics**

# %%
# Hello World
print('Hello World')
# Out:
# Hello World

# %%
#String
print('Sagar Kumar')
# Out:
# Sagar Kumar

# %%
# Python is a case censitive language
print(Sagar Kumar)

#got error because string must be inside comma
# Out:
#   File "/tmp/ipython-input-1696685391.py", line 1
#     print(Sagar Kumar)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Integer
print(7)
# Out:
# 7

# %%
#Float
print(7.7)
# Out:
# 7.7

# %%
#Boolean
print(True)
# Out:
# True

# %%
#combined
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
#sep parameter defined weather its , seperated or anything else like / - etc
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
#python works line by line
print('hello')
print('world')
# Out:
# hello
# world

# %%
# end parameter used to join multiple output with some parameters

print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308   # max possible integer
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
#1*10^308     # max possible float
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List->  in C language -> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %%
# type
type([1,2,3])
# Out:
# list

# %% [markdown]
# # 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
name = 'Sagar'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# Sagar
# 11

# %%
# Dynamic Typing - python
a = 5
# Static Typing - c/c++
int a = 5   # will get error here
# Out:
#   File "/tmp/ipython-input-1639363930.py", line 4
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
# Dynamic Binding
a = 5
print(a)
a = 'nitish'
print(a)

# Static Binding
int a = 5   #will definitely get error here
# Out:
#   File "/tmp/ipython-input-936439154.py", line 8
#     int a = 5   #will definitely get error here
#         ^
# SyntaxError: invalid syntax

# %%
#python smart enough to understand dtype
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords

# %%
# Identifiers
# You can't start with a digit
name1 = 'Nitish'
print(name1)
# You can use special chars -> _
_ = 'ntiish'
print(_)
# identiers can not be keyword
# Out:
# Nitish
# ntiish

# %% [markdown]
# # Temp Heading

# %% [markdown]
# # 5. User Input

# %%
# 1st way
input('Enter Email')
# Out:
# Enter Emailsagar@gmail.com
# 'sagar@gmail.com'

# %%
#2nd way - take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
# add the 2 variables
result = fnum + snum
# print the result
print(result)
print(type(fnum)) #to check the type of output
# Out:
# enter first number25
# enter second number12
# 37
# <class 'int'>

# %% [markdown]
# # 6. Type Conversion

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

print(4 + '4')  #can't add this way (str + int)

# %%
# Explicit
# str -> int
#int(4+5j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %% [markdown]
# # 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
# Complex
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""  # for large str
unicode = u"\U0001f600\U0001F606\U0001F923"   #for unicode like emoji's
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
#Boolean
a = True + 4   #True = 1
b = False + 10 #False = 0

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
#special
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# # **End of lecture 1 fundamentals**
