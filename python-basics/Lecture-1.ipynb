# %% [markdown]
# # **Lecture-1-Python-Basics**

# %% [markdown]
# # 1. Python Output

# %%
# Hello World in Python
print('Hello World')
# Out:
# Hello World

# %%
print('Sagar Kumar')
# Out:
# Sagar Kumar

# %%
# Python is a case sensitive language
print(Sagar Kumar)
# Out:
#   File "/tmp/ipython-input-933766860.py", line 2
#     print(salman khan)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Numbers
print(7)
# Out:
# 7

# %%
#Float
print(7.7)
# Out:
# 7.7

# %%
#Boolean
print(True)
# Out:
# True

# %%
#Combined
print('Sagar',4,3.5,True)
# Out:
# Sagar 4 3.5 True

# %%
#seperator parameter = defined seperation method weather its , / -
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
#python code executed line by line
print('hello')
print('world')
# Out:
# hello
# world

# %%
#end parameter = defined how lines will changes
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308 = max possible integer
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
# 1*10^308 = max possible Float
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List->in python
# Array-> in C/C++
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Sagar','gender':'Male','weight':70})
# Out:
# {'name': 'Sagar', 'gender': 'Male', 'weight': 70}

# %%
# type - to find the dtype
type([1,2,3])
# Out:
# list

# %% [markdown]
# # 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
# Dynamic typing
name = 'Sagar'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# Sagar
# 11

# %%
# Dynamic Typing = used in python
a = 5
# Static Typing = used in C/C++
int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'Sagar'
print(a)

# Static Binding
int a = 5
# Out:
# 5
# Sagar

# %%
#Eg-:
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords

# %%
# Identifiers
# You can't start with a digit
name1 = 'Sagar'
print(name1)
# You can use special chars -> _
_ = 'Sagar'
print(_)
# identiers can not be keyword
# Out:
# Sagar
# Sagar

# %% [markdown]
# # Temp Heading

# %% [markdown]
# # 5. User Input

# %%
# Static Vs Dynamic
input('Enter Email')
# Out:
# Enter Emailsagar@gmail.com
# 'sagar@gmail.com'

# %%
# take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))

# add the 2 variables
result = fnum + snum

# print the result
print(result)
print(type(fnum))
# Out:
# enter first number50
# enter second number60
# 110
# <class 'int'>

# %% [markdown]
# # 6. Type Conversion

# %% [markdown]
# 1.   Implicit
# 2.   Explicit

# %%
# Implicit
print(5+5.6)
print(type(5),type(5.6))

print(4 + '4')  # you can't add str like this
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-72e5c45cdb6f> in <module>
#       3 print(type(5),type(5.6))
#       4
# ----> 5 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int

# int to str
str(5)
print(type(str(5)))

# int to float
float(4)
print(type(float(4)))
# Out:
# <class 'str'>
# <class 'float'>

# %% [markdown]
# # 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
# binary
x = 3.14j
print(x.imag) #only imaginary part
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is also Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923" #incode for Emoji's
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is also Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4   #in python True = 1
b = False + 10 #in python False = 0

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
k = None  #spceial case, will use in future
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# # End-of-Lecture-1
